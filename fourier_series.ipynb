# %% [markdown]
# <a href="https://colab.research.google.com/github/RF-Lab/lab_sources/blob/master/fourier_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 1
omega0  = 2*np.pi/T
t = np.linspace(-T, T, 500, endpoint=False)
sig = np.sign(np.sin( omega0 * t))

fig = plt.figure(figsize=[8,5])
ax = fig.add_subplot(111)

for K in  [2, 5, 15, 400 ]:
  fsig = 0
  for k in range(-K,K):
    if k!=0:
      Xk = -1j/(np.pi*k)*(1-np.cos(np.pi*k))
    else:
      Xk = 0
    fsig = fsig + Xk*np.exp(1j*omega0*k*t)
  nmse = 10*np.log10(np.square(sig-fsig.real).mean()/np.square(sig).mean())
  print('K={0:3}, nmse={1:.3}dB'.format(K,nmse))
  ax.plot(t,fsig.real,label='K={0:3}, nmse={1:.3}dB'.format(K,nmse))
ax.plot(t,sig,label='f(x)')
ax.grid()
ax.legend()
# Out:
# K=  2, nmse=-7.26dB
# K=  5, nmse=-11.3dB
# K= 15, nmse=-16.0dB
# K=400, nmse=-22.2dB
